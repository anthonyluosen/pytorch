# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
# os.listdir()

# %%
path_true = 'C:\\Users\\luzheng\\Desktop\\E\\正常数据\\'
data = pd.read_csv(path_true+'24.正常.txt' ,sep = ':' )

# %%
data.head()
# Out:
#    T  094843750 DecaRangeRTLS  LogFile  z?m  Conf  Tag0    1  Chan2
# 0  T   94843811            RR        0       0  3280  3280  127  15743
# 1  T   94843811            RR        0       1  4660  4660  127  15743
# 2  T   94843811            RR        0       2  2600  2600  127  15743
# 3  T   94843811            RR        0       3  3910  3910  127  15743
# 4  T   94844019            RR        0       0  3280  3280  128  15744

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# import scipy  as S
plt.style.use('fivethirtyeight')
plt.figure(figsize = (16,16))
fig ,ax = plt.subplots(1,4 ,figsize=(14,6))
# data = data.astype('float')
for count,i in enumerate(data_conf.columns[:-1]):
#     sns.displot(data[i] ,bins = 30 )
    sns.distplot(data_conf[i], ax = ax[count])
    ax[count].set(title=i )
    ax[count].set_xlabel('distance')
    plt.title(i)
fig.suptitle('confirm',fontsize = 14) # or plt.suptitle('Main title')

    
# plot the data_tag
fig_tag ,ax_tag = plt.subplots(1,4 ,figsize=(14,6))
plt.style.use('ggplot')
for count,i in enumerate(data_fag.columns[:-1]):
#     sns.displot(data[i] ,bins = 30 )
    sns.distplot(data_fag[i].values, ax = ax_tag[count],color='r')
    ax_tag[count].set(title=i )
    ax_tag[count].set_xlabel('distance')
    plt.title(i)
fig_tag.suptitle('tag',fontsize = 14) # or plt.suptitle('Main title')
# Out:
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# ...

# %%
data_conf.describe()
# Out:
#           postion1     postion2     postion3     postion4     time_tag
# count   539.000000   539.000000   539.000000   539.000000   539.000000
# mean   3581.948052  3863.153989  3746.066790  3995.658627  9704.000000
# std    1334.491991  1281.080978  1293.189956  1283.575282   155.740168
# min     780.000000  1500.000000  1530.000000   830.000000  9435.000000
# 25%    2895.000000  2710.000000  2565.000000  3425.000000  9569.500000
# 50%    3650.000000  4510.000000  3890.000000  4020.000000  9704.000000
# 75%    4410.000000  4745.000000  4790.000000  4680.000000  9838.500000
# max    6390.000000  5680.000000  5690.000000  6530.000000  9973.000000

# %%
data_fag.describe()
#
# Out:
#           postion1     postion2     postion3     postion4     time_tag
# count   539.000000   539.000000   539.000000   539.000000   539.000000
# mean   3581.948052  3863.153989  3746.066790  3995.658627  9704.000000
# std    1334.491991  1281.080978  1293.189956  1283.575282   155.740168
# min     780.000000  1500.000000  1530.000000   830.000000  9435.000000
# 25%    2895.000000  2710.000000  2565.000000  3425.000000  9569.500000
# 50%    3650.000000  4510.000000  3890.000000  4020.000000  9704.000000
# 75%    4410.000000  4745.000000  4790.000000  4680.000000  9838.500000
# max    6390.000000  5680.000000  5690.000000  6530.000000  9973.000000

# %%
data_fag.plot()
# Out:
# <AxesSubplot:>

# %%
tag_position = pd.read_csv('Tag坐标信息.txt' ,sep = ' ' )
print(tag_position.head())
l = ['Unnamed: 4','Unnamed: 5','88']
tag_position = tag_position.drop(l,axis=1)
tag_position.columns = ['code' , 'X' , 'Y' , 'Z']
# Out:
#    1:  50  50.1  Unnamed: 3  Unnamed: 4  Unnamed: 5  88
# 0  2:  50   100        88.0         NaN         NaN NaN
# 1  3:  50   150        88.0         NaN         NaN NaN
# 2  4:  50   200        88.0         NaN         NaN NaN
# 3  5:  50   250        88.0         NaN         NaN NaN
# 4  6:  50   300        88.0         NaN         NaN NaN

# %%
import plotly.express as px
# df = px.data.iris()
fig = px.scatter_3d(tag_position, x='X', y='Y', z='Z',
              )
fig.show()
# Out:
# <div>                            <div id="0cd49163-2201-456a-94ae-37f33a4292ac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0cd49163-2201-456a-94ae-37f33a4292ac")) {                    Plotly.newPlot(                        "0cd49163-2201-456a-94ae-37f33a4292ac",                        [{"hovertemplate": "X=%{x}<br>Y=%{y}<br>Z=%{z}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "", "scene": "scene", "showlegend": false, "type": "scatter3d", "x": [50, 50, 50, 50, 50, 50, 50, 50, 100, 100, 100, 100, 100, 100, 100, 100, 100, 150, 150, 150, 150, 150, 150, 150, 150, 150, 200, 200, 200, 200, 200, 200, 200, 200, 200, 250, 250, 250, 250, 250, 250, 250, 250, 250, 300, 300, 300, 300, 300,
# ...

# %%
fig = plt.figure()
ax = plt.axes(projection ='3d')
ax.plot3D(tag_position['X'], tag_position['Y'], tag_position['Z'], 'green')

# %%
path_anomaly = 'C:\\Users\\luzheng\\Desktop\\E\\异常数据\\'
path_true = 'C:\\Users\\luzheng\\Desktop\\E\\正常数据\\'
data_fake_1 = pd.read_csv(path_anomaly+'2.异常.txt' , sep = ':')
data_real_1 = pd.read_csv(path_true+'2.正常.txt' , sep = ':')

# %%
def transform(data):
    whole_tag = []
    name = data.columns[1]
    for i in data.groupby(name)['Tag0']:
        a = list(i[1])
        if len(a)!=4:
            while True:
                a.append('nan')
                if len(a) == 4:
                    break
        time = i[0]
        a.append(time)
        whole_tag.append(a)
    data_fag = pd.DataFrame(whole_tag, columns = ['postion1' ,'postion2','postion3','postion4','time_tag' ])
    data_fag = data_fag.astype('float')
    return data_fag

# %%
data_fake_1_t = transform(data_fake_1)
data_real_1_t = transform(data_real_1)

plt.style.use('fivethirtyeight')
plt.figure(figsize = (16,16))
fig ,ax = plt.subplots(1,4 ,figsize=(14,6))
# data = data.astype('float')
for count,i in enumerate(data_real_1_t.columns[:-1]):
#     sns.displot(data[i] ,bins = 30 )
    sns.distplot(data_real_1_t[i], ax = ax[count])
    ax[count].set(title=i )
    ax[count].set_xlabel('distance')
    plt.title(i)
fig.suptitle('real',fontsize = 14) # or plt.suptitle('Main title')

# plot the data_tag
fig_tag ,ax_tag = plt.subplots(1,4 ,figsize=(14,6))
for count,i in enumerate(data_fake_1_t.columns[:-1]):
#     sns.displot(data[i] ,bins = 30 )
    sns.distplot(data_fake_1_t[i].values, ax = ax_tag[count],color='r')
    ax_tag[count].set(title=i )
    ax_tag[count].set_xlabel('distance')
    plt.title(i)
fig_tag.suptitle('fake',fontsize = 14) # or plt.suptitle('Main title')
# Out:
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# ...

# %%
plt.figure(figsize = (16,16))
data_fake_1_t.drop('time_tag',axis=1).plot()
# Out:
# <AxesSubplot:>

# %%
data_fake_1_t.isnull().sum()
# Out:
# postion1     0
# postion2    33
# postion3    45
# postion4    78
# time_tag     0
# dtype: int64

# %%
data_real_1_t.isnull().sum()
# Out:
# postion1     0
# postion2    33
# postion3    45
# postion4    78
# time_tag     0
# dtype: int64

# %%
fig ,ax = plt.subplots(1,2,figsize = (16,14))
ax[0].plot(data_real_1_t['postion4'])
ax[1].plot(data_fake_1_t['postion4'])

# %%
n = data_real_1_t.dropna(axis=0)

# %%
n = n.drop_duplicates(subset = ['postion1' ,'postion2','postion3' ,'postion4'] , keep = 'first')

# %%
n.drop('time_tag' ,axis = 1).plot()
plt.xlabel('time')
plt.ylabel('position')
plt.title('real')
# Out:
# Text(0.5, 1.0, 'real')

# %%
f = data_fake_1_t.dropna(axis=0)
f = f.drop_duplicates(subset = ['postion1' ,'postion2','postion3' ,'postion4'] , keep = 'first')
f.drop('time_tag' ,axis = 1).plot()
plt.xlabel('time')
plt.ylabel('position')
plt.title('fake')
# Out:
# Text(0.5, 1.0, 'fake')

# %%
plt.figure(figsize = (16,16))
plt.scatter(f.index , f['postion1'])

# %%
plt.figure(figsize = (16,16))
plt.scatter(f.index , f['postion4'])

# %%
plt.figure(figsize = (16,16))
plt.scatter(n.index , n['postion1'])

# %%
# data_fake_2 = pd.read_csv(path_anomaly+'2.异常.txt' , sep = ':')
data_real_2 = pd.read_csv(path_true+'3.正常.txt' , sep = ':')
print(len(data_real_2))
# data_fake_2 = transform(data_fake_2)
data_real_2 = transform(data_real_2)
print(len(data_real_2))
# Out:
# 776
# 215

# %%
plt.scatter(data_fake_2.index,data_fake_2['postion2'])

# %%
plt.scatter(data_real_2.index,data_real_2['postion2'])

# %%
# Take useful feature and standardize them
from sklearn import preprocessing
from sklearn.decomposition import PCA
df = data_real_2.copy()
df = df.dropna(axis=0)
# print(len(df))
# delete duplicate data
df = df.drop_duplicates(subset = ['postion1' ,'postion2','postion3' ,'postion4'] , keep = 'first')
df.reset_index(inplace = True)
data = df[['postion1' ,'postion2','postion3' ,'postion4']]
print(len(df))
min_max_scaler = preprocessing.StandardScaler()
np_scaled = min_max_scaler.fit_transform(data)
data = pd.DataFrame(np_scaled)
print(len(data))
# reduce to 2 importants features
pca = PCA(n_components=2)
data = pca.fit_transform(data)
# standardize these 2 new features
min_max_scaler = preprocessing.StandardScaler()
np_scaled = min_max_scaler.fit_transform(data)
data = pd.DataFrame(np_scaled)
# Out:
# 93
# 93

# %%
# calculate with different number of centroids to see the loss plot (elbow method)
from sklearn.cluster import KMeans
plt.style.use('ggplot')
n_cluster = range(1, 20)
kmeans = [KMeans(n_clusters=i).fit(data) for i in n_cluster]
scores = [kmeans[i].score(data) for i in range(len(kmeans))]
fig, ax = plt.subplots()
ax.plot(n_cluster, scores)
plt.show()

# %%
# data = pd.DataFrame(data)

# %%
df['cluster'] = kmeans[14].predict(data)
df['principal_feature1'] = data[0]
df['principal_feature2'] = data[1]
df['cluster'].value_counts()
df
# Out:
#     index  postion1  postion2  postion3  postion4    time_tag  cluster  \
# 0       0    1090.0    4690.0    4120.0    5950.0  90250469.0        3
# 1       1    1090.0    4690.0    4120.0    5940.0  90250677.0        3
# 2       2    1090.0    4680.0    4120.0    5930.0  90250885.0        6
# 3       3    1090.0    4680.0    4110.0    5940.0  90251093.0        4
# 4       4    1100.0    4670.0    4110.0    5940.0  90251301.0        9
# ..    ...       ...       ...       ...       ...         ...      ...
# 88    177    1120.0    4680.0    4110.0    5950.0  90324205.0       14
# 89    178    1100.0    4690.0    4120.0    5960.0  90324413.0       11
# 90    179    1100.0    4680.0    4110.0    5960.0  90324621.0        0
# 91    180    1110.0    4690.0    4100.0    5950.0  90324829.0        8
# 92    181    1120.0    4680.0    4100.0    5960.0  90325037.0        8
#
#     principal_feature1  principal_feature2
# 0             1.579352            1.114770
# ...

# %%
#plot the different clusters with the 2 main features
fig, ax = plt.subplots()
colors = {0:'red', 1:'blue', 2:'green', 3:'pink', 4:'black', 5:'orange', 6:'cyan',
          7:'yellow', 8:'brown', 9:'purple', 10:'white', 11: 'grey', 12:'lightblue', 13:'lightgreen', 
          14: 'darkgrey',}
ax.scatter(df['principal_feature1'], df['principal_feature2'], c=df["cluster"].apply(lambda x: colors[x]))
plt.show()

# %%
# get the distance between each point and its nearest centroid. The biggest distances are considered as anomaly
outliers_fraction = 0.16
def getDistanceByPoint(data, model):
    distance = pd.Series(dtype='float64')
    for i in range(0,len(data)):
        Xa = np.array(data.loc[i])
        Xb = model.cluster_centers_[model.labels_[i]-1]
        distance.at[i] =  np.linalg.norm(Xa-Xb)
    return distance
distance = getDistanceByPoint(data, kmeans[14])
number_of_outliers = int(outliers_fraction*len(distance))
threshold = distance.nlargest(number_of_outliers).min()
# anomaly21 contain the anomaly result of method 2.1 Cluster (0:normal, 1:anomaly) 
df['anomaly21'] = (distance >= threshold).astype(int)

# %%
# data = data.values
df['anomaly21'].value_counts()
# Out:
# 0    79
# 1    14
# Name: anomaly21, dtype: int64

# %%
fig, ax = plt.subplots()
colors = {0:'blue', 1:'red'}
ax.scatter(df['principal_feature1'], df['principal_feature2'], 
           c=df["anomaly21"].apply(lambda x: colors[x]))
# plt.legend(=['real' ， 'fake'])
plt.show()

# %%
# visualisation of anomaly with temperature repartition (viz 2)
a = df.loc[df['anomaly21'] == 0, 'postion1']
b = df.loc[df['anomaly21'] == 1, 'postion1']

fig, axs = plt.subplots()
axs.hist([a,b], bins=32, stacked=True, color=['blue', 'red'], label=['normal', 'anomaly'])
plt.legend()
plt.show()

# %%
df_clean = df.drop(df[df['anomaly21']==1].index, axis = 0)
plt.scatter(df_clean.index,df_clean['postion2'])

# %%
df
# Out:
#     index  postion1  postion2  postion3  postion4    time_tag  cluster  \
# 0       0    1090.0    4690.0    4120.0    5950.0  90250469.0        7
# 1       1    1090.0    4690.0    4120.0    5940.0  90250677.0        2
# 2       2    1090.0    4680.0    4120.0    5930.0  90250885.0        6
# 3       3    1090.0    4680.0    4110.0    5940.0  90251093.0        2
# 4       4    1100.0    4670.0    4110.0    5940.0  90251301.0       13
# ..    ...       ...       ...       ...       ...         ...      ...
# 88    177    1120.0    4680.0    4110.0    5950.0  90324205.0        1
# 89    178    1100.0    4690.0    4120.0    5960.0  90324413.0        7
# 90    179    1100.0    4680.0    4110.0    5960.0  90324621.0       14
# 91    180    1110.0    4690.0    4100.0    5950.0  90324829.0        8
# 92    181    1120.0    4680.0    4100.0    5960.0  90325037.0       10
#
#     principal_feature1  principal_feature2  anomaly21
# 0             1.579352            1.114770          0
# ...

# %%
#dfine the model to delete the anomaly data
import pandas as pd
df_109 = pd.read_csv('data_real_109.csv')
df_109
# Out:
#      Unnamed: 0  postion1  postion2  postion3  postion4
# 0             0    4910.0    5310.0    2030.0    2870.0
# 1             1    4920.0    5310.0    2020.0    2870.0
# 2             2    4920.0    5310.0    2020.0    2880.0
# 3             3    4910.0    5310.0    2020.0    2880.0
# 4             4    4910.0    5310.0    2020.0    2870.0
# ..          ...       ...       ...       ...       ...
# 114         114    4910.0    5340.0    2040.0    2890.0
# 115         115    4910.0    5350.0    2040.0    2880.0
# 116         116    4910.0    5350.0    2050.0    2870.0
# 117         117    4910.0    5350.0    2040.0    2870.0
# 118         118    4910.0    5340.0    2040.0    2870.0
#
# [119 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
fig_tag ,ax_tag = plt.subplots(1,4 ,figsize=(14,6))
for count,i in enumerate(df_109.columns[1:]):
#     sns.displot(data[i] ,bins = 30 )
    sns.distplot(df_109[i].values, ax = ax_tag[count],color='r' , bins = 10)
    ax_tag[count].set(title=i )
    ax_tag[count].set_xlabel('distance')
    plt.title(i)
fig_tag.suptitle('fake',fontsize = 14) # or plt.suptitle('Main title')
# Out:
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# ...
