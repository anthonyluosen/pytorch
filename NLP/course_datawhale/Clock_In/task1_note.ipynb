# %% [markdown]
# ### what i learn
# the most import thing:
# 1:I gonna use RNN and LSTM and Bert to do the sentiment analysis.
# 2:The basic platform building(which i 've already done before)
# 3:Now i know i could actually use the CNN to do sentiment analysis and the paper was come from :<br>
# https://arxiv.org/abs/1408.5882<br>
# here i show the model structure below:<br>
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %% [markdown]
# ## next i would  construct the model to see its actual performce
# and there are the paper today(2021/9/13)i don't have the time to read and i would the the paper link below:<br>
# https://arxiv.org/abs/1607.01759
