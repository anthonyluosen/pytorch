# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import os 
import pandas as pd

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'drawing.ipynb',
#  'end_to_end.ipynb',
#  'final.ipynb',
#  'task2.ipynb',
#  '位置预测加上classification.h5',
#  '就是你了.csv',
#  '搞过的数据.csv',
#  '第2次分类结果.h5',
#  '第三个双模型均进一步优化.csv',
#  '第三次拟合算法_求位置.h5',
#  '第二次进一步优化位置模型.csv',
#  '轨迹图.csv',
#  '轨迹图用第五次位置模型.csv',
#  '附件5：动态轨迹数据.txt']

# %%
d1 = pd.read_csv('轨迹图.csv')
d2 = pd.read_csv('第二次进一步优化位置模型.csv')
d3 = pd.read_csv('第三个双模型均进一步优化.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sns; 
sns.set()

sns.scatterplot( x="X", y="Y",data=d1)
plt.title('')
plt.show()
# Out:
# C:\anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 21021 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 20540 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 27169 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 22411 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 36712 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 36857 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
from mpl_toolkits.mplot3d import axes3d

ax = plt.axes(projection='3d')
x = d1['X']
y = d1['Y']
z = d1['Z']

ax.scatter3D(x,y,z)
ax.set_xlabel('X Axes')
ax.set_ylabel('Y Axes')
ax.set_zlabel('Z Axes')

plt.show()

# %%
sns.scatterplot( x="X", y="Y",data=d2)
plt.title('')
plt.show()

# %%
ax = plt.axes(projection='3d')
x = d2['X']
y = d2['Y']
z = d2['Z']

ax.scatter3D(x,y,z)
ax.set_xlabel('X Axes')
ax.set_ylabel('Y Axes')
ax.set_zlabel('Z Axes')

plt.show()

# %%
sns.scatterplot( x="X", y="Y",data=d3)
plt.title('')
plt.show()

# %%
ax = plt.axes(projection='3d')
x = d3['X']
y = d3['Y']
z = d3['Z']

ax.scatter(x,y,z)
ax.set_xlabel('X Axes')
ax.set_ylabel('Y Axes')
ax.set_zlabel('Z Axes')

plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-907e79a9245c> in <module>
# ----> 1 sns.scatterplot( x=position_final.index, y="Z",data=d1)
#       2 plt.show()
#
# NameError: name 'position_final' is not defined

# %%
sns.scatterplot( x=d1.index, y="Z",data=d1)
# Out:
# <AxesSubplot:ylabel='Z'>

# %%
sns.scatterplot( x=d1.index, y="Z",data=d2)
# Out:
# <AxesSubplot:ylabel='Z'>

# %%
sns.scatterplot( x=d1.index, y="Z",data=d3)
# Out:
# <AxesSubplot:ylabel='Z'>
