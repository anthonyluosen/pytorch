# %% [markdown]
# 将数据处理成新的数据喂进模型，本次探索为第四大题和第五大题服务。根据数据建立模型:
# 目前比较流行得模型是以神经网络作为主流得机器学习模型，其中学术环境中测试最为有效的环境是CNN和LSTM
# 名字分别为，Convolutional Neural NetWork,Long Short Term Merrmory,前者能有效截取片段，后者的神经元具有记忆特性的优点，往往有文章将两者结合一起进行训练会有比较好的结果，但是本次由于时限原因，只采取<<Improving Deep Learning-Based UWB LOS/NLOS Identification with Transfer Learning:An Empirical Approach>>该文章。链接:https://www.mdpi.com/2079-9292/9/10/1714<br>
# 下面为本文的模型结构图:
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)
# 但是考虑本次实验的数据结构，模型的样式和维度会有稍微的变化

# %% [markdown]
# 任务中对附件4的一个描述，说明了对数据点的处理是单个点的处理，及判断单个数据是否为在干扰情况下的数据，所以任务五的一个行文思路便是用优化好的模型去筛掉为干扰后的数据组，并进行删除，此时得到已经经过去除干扰且在之前经过数据清理的数据。<br>
# 值得注意的是本文的数据异常和正常处理有不同数量的数据组，所以为了平衡数据，在这里我们训练40%的干扰数据以及50%的未干扰数据。

# %%
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# class n_LOSnet(nn.Module):
#     def __init__(self , input_size , hidden_size):
#         super(neuralnet , self).__init__()
#         self.linear1 = nn.Linear(hidden_size  ,hidden_size)
#         self.relu = nn.relu()
#         self.linear2 = nn.Linear(hidden_size , 1)
#         self.softmax = nn.softmax()
        
#     def forward(self ,x):
#         x = self.relu(self.linear1(x))
#         x = self

# %%
import os
import pandas as pd
import numpy as np
# print(os.listdir())
los = pd.read_csv('处理后无干扰的数据.csv')
nlos = pd.read_csv('处理后有干扰的数据.csv')
print(los.head())
print(nlos.head())
print(f'干扰后数据有{len(nlos)} ,干扰后的数据有{len(los)}')
# Out:
#    Unnamed: 0  position1  position2  position3  position4  code
# 0           0      750.0     4550.0     4550.0     6300.0     1
# 1           1      750.0     4550.0     4560.0     6300.0     1
# 2           2      750.0     4540.0     4560.0     6310.0     1
# 3           3      780.0     4550.0     4550.0     6300.0     1
# 4           4      780.0     4550.0     4550.0     6310.0     1
#    Unnamed: 0  position1  position2  position3  position4  code
# 0           0     1220.0     4550.0     4550.0     6290.0     1
# 1           1      750.0     5050.0     4540.0     6310.0     1
# 2           2     1290.0     4540.0     4540.0     6310.0     1
# 3           3      780.0     5010.0     4540.0     6300.0     1
# 4           4     1250.0     4550.0     4560.0     6290.0     1
# 干扰后数据有26979 ,干扰后的数据有22833

# %%
# 0表示为无干扰
los_= los[['position1'  ,'position2' , 'position3' , 'position4']]
los_['los/nlos'] = 0 
nlos_ = nlos[['position1'  ,'position2' , 'position3' , 'position4']]
nlos_['los/nlos'] = 1
# Out:
# <ipython-input-2-70b9511c0966>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   los_['los/nlos'] = 0
# <ipython-input-2-70b9511c0966>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nlos_['los/nlos'] = 1

# %%
los_.head()
# Out:
#    position1  position2  position3  position4  los/nlos
# 0      750.0     4550.0     4550.0     6300.0         0
# 1      750.0     4550.0     4560.0     6300.0         0
# 2      750.0     4540.0     4560.0     6310.0         0
# 3      780.0     4550.0     4550.0     6300.0         0
# 4      780.0     4550.0     4550.0     6310.0         0

# %%
nlos_.head()
# Out:
#    position1  position2  position3  position4  los/nlos
# 0     1220.0     4550.0     4550.0     6290.0         1
# 1      750.0     5050.0     4540.0     6310.0         1
# 2     1290.0     4540.0     4540.0     6310.0         1
# 3      780.0     5010.0     4540.0     6300.0         1
# 4     1250.0     4550.0     4560.0     6290.0         1

# %%
# los_.append(nlos_)
data = los_.append(nlos_)
len(data)
# Out:
# 49812

# %%
from sklearn.preprocessing import StandardScaler , RobustScaler
rob = RobustScaler()
data_scaled = rob.fit_transform(data[['position1'  ,'position2' , 'position3' , 'position4']])
data_scaled
# Out:
# array([[-1.73513514,  0.3027027 ,  0.3027027 ,  1.24864865],
#        [-1.73513514,  0.3027027 ,  0.30810811,  1.24864865],
#        [-1.73513514,  0.2972973 ,  0.30810811,  1.25405405],
#        ...,
#        [-1.63783784,  0.04864865,  0.29189189,  1.33513514],
#        [-1.38918919,  0.05405405,  0.28648649,  1.09189189],
#        [-1.37297297,  0.05405405,  0.28648649,  1.08108108]])

# %%
data_scaled = pd.DataFrame(data_scaled)
station_p = np.array([0,0,1300,5000,0,1700,0,5000,1700,5000,5000,1300])/1000
data_scaled[['A01','A02','A03','A11','A12','A13','A21','A22','A23','A31','A32','A33']]=station_p
data_scaled.head()
# Out:
#           0         1         2         3  A01  A02  A03  A11  A12  A13  A21  \
# 0 -1.735135  0.302703  0.302703  1.248649  0.0  0.0  1.3  5.0  0.0  1.7  0.0
# 1 -1.735135  0.302703  0.308108  1.248649  0.0  0.0  1.3  5.0  0.0  1.7  0.0
# 2 -1.735135  0.297297  0.308108  1.254054  0.0  0.0  1.3  5.0  0.0  1.7  0.0
# 3 -1.718919  0.302703  0.302703  1.248649  0.0  0.0  1.3  5.0  0.0  1.7  0.0
# 4 -1.718919  0.302703  0.302703  1.254054  0.0  0.0  1.3  5.0  0.0  1.7  0.0
#
#    A22  A23  A31  A32  A33
# 0  5.0  1.7  5.0  5.0  1.3
# 1  5.0  1.7  5.0  5.0  1.3
# 2  5.0  1.7  5.0  5.0  1.3
# 3  5.0  1.7  5.0  5.0  1.3
# 4  5.0  1.7  5.0  5.0  1.3

# %%
data
# Out:
#        position1  position2  position3  position4  los/nlos
# 0          750.0     4550.0     4550.0     6300.0         0
# 1          750.0     4550.0     4560.0     6300.0         0
# 2          750.0     4540.0     4560.0     6310.0         0
# 3          780.0     4550.0     4550.0     6300.0         0
# 4          780.0     4550.0     4550.0     6310.0         0
# ...          ...        ...        ...        ...       ...
# 26974     1390.0     4090.0     4530.0     5990.0         1
# 26975      930.0     4080.0     4520.0     6450.0         1
# 26976      930.0     4080.0     4530.0     6460.0         1
# 26977     1390.0     4090.0     4520.0     6010.0         1
# 26978     1420.0     4090.0     4520.0     5990.0         1
#
# [49812 rows x 5 columns]

# %%
import tensorflow as tf 
from tensorflow.keras import backend as b
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from sklearn.model_selection import train_test_split

X = data_scaled.values
y = data['los/nlos']

x_train , x_test , y_train , y_test = train_test_split(X , y , train_size=0.8 )

n_inputs = x_train.shape[1]
model = Sequential([
    Dense(n_inputs , input_shape=(n_inputs, ) , activation = 'relu'),
    Dense(128 , activation = 'relu'),
    Dense(256 , activation = 'relu'),
    Dense(256 , activation = 'relu'),
    Dense(512 , activation = 'softmax')
])

# %%
model.compile(Adam(lr=0.001) , loss = 'sparse_categorical_crossentropy',
             metrics = ['accuracy'])

# %%
his1 = model.fit(x_train , y_train , validation_split=0.2 ,  epochs=130 ,
          batch_size=64 ,shuffle=True , verbose=2
         )
# Out:
# Epoch 1/130
# 499/499 - 2s - loss: 0.7652 - accuracy: 0.5314 - val_loss: 0.6617 - val_accuracy: 0.6098
# Epoch 2/130
# 499/499 - 2s - loss: 0.6050 - accuracy: 0.6637 - val_loss: 0.6822 - val_accuracy: 0.6304
# Epoch 3/130
# 499/499 - 2s - loss: 0.4871 - accuracy: 0.7609 - val_loss: 0.4507 - val_accuracy: 0.7839
# Epoch 4/130
# 499/499 - 2s - loss: 0.4423 - accuracy: 0.7813 - val_loss: 0.4181 - val_accuracy: 0.8015
# Epoch 5/130
# 499/499 - 2s - loss: 0.4276 - accuracy: 0.7889 - val_loss: 0.4107 - val_accuracy: 0.7903
# Epoch 6/130
# 499/499 - 2s - loss: 0.4134 - accuracy: 0.7927 - val_loss: 0.4154 - val_accuracy: 0.7934
# Epoch 7/130
# 499/499 - 2s - loss: 0.4125 - accuracy: 0.7936 - val_loss: 0.3871 - val_accuracy: 0.8073
# Epoch 8/130
# 499/499 - 2s - loss: 0.4050 - accuracy: 0.7986 - val_loss: 0.3889 - val_accuracy: 0.8055
# Epoch 9/130
# 499/499 - 2s - loss: 0.4072 - accuracy: 0.7934 - val_loss: 0.3892 - val_accuracy: 0.8064
# Epoch 10/130
# 499/499 - 2s - loss: 0.4002 - accuracy: 0.7978 - val_loss: 0.3857 - val_accuracy: 0.8063
# Epoch 11/130
# 499/499 - 2s - loss: 0.3995 - accuracy: 0.7971 - val_loss: 0.3777 - val_accuracy: 0.8074
# Epoch 12/130
# 499/499 - 2s - loss: 0.3903 - accuracy: 0.8021 - val_loss: 0.4416 - val_accuracy: 0.7864
# Epoch 13/130
# 499/499 - 2s - loss: 0.3962 - accuracy: 0.8006 - val_loss: 0.6595 - val_accuracy: 0.7159
# Epoch 14/130
# 499/499 - 2s - loss: 0.3883 - accuracy: 0.8032 - val_loss: 0.4452 - val_accuracy: 0.7798
# Epoch 15/130
# 499/499 - 2s - loss: 0.3852 - accuracy: 0.8044 - val_loss: 0.3722 - val_accuracy: 0.8162
# Epoch 16/130
# 499/499 - 2s - loss: 0.3800 - accuracy: 0.8096 - val_loss: 0.3954 - val_accuracy: 0.8021
# Epoch 17/130
# 499/499 - 2s - loss: 0.3832 - accuracy: 0.8069 - val_loss: 0.3753 - val_accuracy: 0.8097
# Epoch 18/130
# 499/499 - 2s - loss: 0.3713 - accuracy: 0.8108 - val_loss: 0.3527 - val_accuracy: 0.8164
# Epoch 19/130
# 499/499 - 2s - loss: 0.3661 - accuracy: 0.8144 - val_loss: 0.3626 - val_accuracy: 0.8090
# Epoch 20/130
# 499/499 - 2s - loss: 0.3600 - accuracy: 0.8179 - val_loss: 0.3500 - val_accuracy: 0.8245
# Epoch 21/130
# 499/499 - 2s - loss: 0.3511 - accuracy: 0.8228 - val_loss: 0.4043 - val_accuracy: 0.8099
# Epoch 22/130
# 499/499 - 2s - loss: 0.3397 - accuracy: 0.8305 - val_loss: 0.3311 - val_accuracy: 0.8332
# Epoch 23/130
# 499/499 - 2s - loss: 0.3297 - accuracy: 0.8351 - val_loss: 0.3456 - val_accuracy: 0.8247
# Epoch 24/130
# 499/499 - 2s - loss: 0.3270 - accuracy: 0.8397 - val_loss: 0.3011 - val_accuracy: 0.8494
# Epoch 25/130
# 499/499 - 2s - loss: 0.3127 - accuracy: 0.8443 - val_loss: 0.2877 - val_accuracy: 0.8604
# Epoch 26/130
# 499/499 - 2s - loss: 0.3115 - accuracy: 0.8469 - val_loss: 0.2916 - val_accuracy: 0.8576
# Epoch 27/130
# 499/499 - 2s - loss: 0.3079 - accuracy: 0.8488 - val_loss: 0.2751 - val_accuracy: 0.8686
# Epoch 28/130
# 499/499 - 2s - loss: 0.3083 - accuracy: 0.8467 - val_loss: 0.2840 - val_accuracy: 0.8556
# Epoch 29/130
# 499/499 - 2s - loss: 0.2931 - accuracy: 0.8573 - val_loss: 0.2604 - val_accuracy: 0.8724
# Epoch 30/130
# 499/499 - 2s - loss: 0.2902 - accuracy: 0.8567 - val_loss: 0.3422 - val_accuracy: 0.8381
# Epoch 31/130
# 499/499 - 2s - loss: 0.2860 - accuracy: 0.8597 - val_loss: 0.2949 - val_accuracy: 0.8588
# Epoch 32/130
# 499/499 - 2s - loss: 0.2967 - accuracy: 0.8548 - val_loss: 0.3106 - val_accuracy: 0.8425
# Epoch 33/130
# 499/499 - 2s - loss: 0.3049 - accuracy: 0.8480 - val_loss: 0.2848 - val_accuracy: 0.8614
# Epoch 34/130
# 499/499 - 2s - loss: 0.3012 - accuracy: 0.8492 - val_loss: 0.2658 - val_accuracy: 0.8698
# Epoch 35/130
# 499/499 - 2s - loss: 0.2788 - accuracy: 0.8641 - val_loss: 0.3174 - val_accuracy: 0.8492
# Epoch 36/130
# 499/499 - 2s - loss: 0.2801 - accuracy: 0.8639 - val_loss: 0.2615 - val_accuracy: 0.8782
# Epoch 37/130
# 499/499 - 2s - loss: 0.2687 - accuracy: 0.8746 - val_loss: 0.3148 - val_accuracy: 0.8498
# Epoch 38/130
# 499/499 - 2s - loss: 0.2627 - accuracy: 0.8771 - val_loss: 0.2672 - val_accuracy: 0.8693
# Epoch 39/130
# 499/499 - 2s - loss: 0.2596 - accuracy: 0.8751 - val_loss: 0.2326 - val_accuracy: 0.8851
# Epoch 40/130
# 499/499 - 2s - loss: 0.2369 - accuracy: 0.8881 - val_loss: 0.2467 - val_accuracy: 0.8787
# Epoch 41/130
# 499/499 - 2s - loss: 0.2438 - accuracy: 0.8857 - val_loss: 0.2124 - val_accuracy: 0.9041
# Epoch 42/130
# 499/499 - 1s - loss: 0.2351 - accuracy: 0.8892 - val_loss: 0.2252 - val_accuracy: 0.8957
# Epoch 43/130
# 499/499 - 1s - loss: 0.2321 - accuracy: 0.8897 - val_loss: 0.2300 - val_accuracy: 0.8910
# Epoch 44/130
# 499/499 - 2s - loss: 0.2295 - accuracy: 0.8920 - val_loss: 0.2582 - val_accuracy: 0.8769
# Epoch 45/130
# 499/499 - 2s - loss: 0.2538 - accuracy: 0.8795 - val_loss: 0.2693 - val_accuracy: 0.8757
# Epoch 46/130
# 499/499 - 2s - loss: 0.2300 - accuracy: 0.8924 - val_loss: 0.2040 - val_accuracy: 0.9113
# Epoch 47/130
# 499/499 - 2s - loss: 0.2132 - accuracy: 0.9022 - val_loss: 0.2093 - val_accuracy: 0.9029
# Epoch 48/130
# 499/499 - 2s - loss: 0.2180 - accuracy: 0.8983 - val_loss: 0.3087 - val_accuracy: 0.8483
# Epoch 49/130
# 499/499 - 2s - loss: 0.2172 - accuracy: 0.8994 - val_loss: 0.1942 - val_accuracy: 0.9105
# Epoch 50/130
# 499/499 - 2s - loss: 0.2062 - accuracy: 0.9037 - val_loss: 0.2268 - val_accuracy: 0.9051
# Epoch 51/130
# 499/499 - 2s - loss: 0.2141 - accuracy: 0.9023 - val_loss: 0.1862 - val_accuracy: 0.9133
# Epoch 52/130
# 499/499 - 2s - loss: 0.2020 - accuracy: 0.9057 - val_loss: 0.2059 - val_accuracy: 0.9046
# Epoch 53/130
# 499/499 - 2s - loss: 0.2021 - accuracy: 0.9086 - val_loss: 0.1837 - val_accuracy: 0.9166
# Epoch 54/130
# 499/499 - 2s - loss: 0.1922 - accuracy: 0.9133 - val_loss: 0.2529 - val_accuracy: 0.8778
# Epoch 55/130
# 499/499 - 2s - loss: 0.1979 - accuracy: 0.9093 - val_loss: 0.3529 - val_accuracy: 0.8542
# Epoch 56/130
# 499/499 - 1s - loss: 0.2037 - accuracy: 0.9080 - val_loss: 0.2081 - val_accuracy: 0.9073
# Epoch 57/130
# 499/499 - 2s - loss: 0.1969 - accuracy: 0.9107 - val_loss: 0.2262 - val_accuracy: 0.8946
# Epoch 58/130
# 499/499 - 2s - loss: 0.1749 - accuracy: 0.9228 - val_loss: 0.1744 - val_accuracy: 0.9238
# Epoch 59/130
# 499/499 - 2s - loss: 0.1838 - accuracy: 0.9188 - val_loss: 0.2903 - val_accuracy: 0.8780
# Epoch 60/130
# 499/499 - 2s - loss: 0.1949 - accuracy: 0.9157 - val_loss: 0.1644 - val_accuracy: 0.9233
# Epoch 61/130
# 499/499 - 2s - loss: 0.1822 - accuracy: 0.9207 - val_loss: 0.1662 - val_accuracy: 0.9306
# Epoch 62/130
# 499/499 - 2s - loss: 0.1941 - accuracy: 0.9131 - val_loss: 0.1711 - val_accuracy: 0.9243
# Epoch 63/130
# 499/499 - 2s - loss: 0.1739 - accuracy: 0.9211 - val_loss: 0.1633 - val_accuracy: 0.9243
# Epoch 64/130
# 499/499 - 2s - loss: 0.1790 - accuracy: 0.9205 - val_loss: 0.1867 - val_accuracy: 0.9207
# Epoch 65/130
# 499/499 - 2s - loss: 0.1832 - accuracy: 0.9215 - val_loss: 0.2223 - val_accuracy: 0.9019
# Epoch 66/130
# 499/499 - 1s - loss: 0.1757 - accuracy: 0.9230 - val_loss: 0.1514 - val_accuracy: 0.9314
# Epoch 67/130
# 499/499 - 2s - loss: 0.1703 - accuracy: 0.9241 - val_loss: 0.1478 - val_accuracy: 0.9399
# Epoch 68/130
# 499/499 - 1s - loss: 0.1737 - accuracy: 0.9245 - val_loss: 0.1447 - val_accuracy: 0.9356
# Epoch 69/130
# 499/499 - 2s - loss: 0.1610 - accuracy: 0.9299 - val_loss: 0.1670 - val_accuracy: 0.9265
# Epoch 70/130
# 499/499 - 2s - loss: 0.1646 - accuracy: 0.9293 - val_loss: 0.1480 - val_accuracy: 0.9385
# Epoch 71/130
# 499/499 - 2s - loss: 0.1627 - accuracy: 0.9299 - val_loss: 0.1443 - val_accuracy: 0.9442
# Epoch 72/130
# 499/499 - 2s - loss: 0.1682 - accuracy: 0.9267 - val_loss: 0.1753 - val_accuracy: 0.9256
# Epoch 73/130
# 499/499 - 2s - loss: 0.1546 - accuracy: 0.9324 - val_loss: 0.1694 - val_accuracy: 0.9284
# Epoch 74/130
# 499/499 - 2s - loss: 0.1584 - accuracy: 0.9329 - val_loss: 0.1585 - val_accuracy: 0.9261
# Epoch 75/130
# 499/499 - 2s - loss: 0.1451 - accuracy: 0.9385 - val_loss: 0.1537 - val_accuracy: 0.9329
# Epoch 76/130
# 499/499 - 2s - loss: 0.1584 - accuracy: 0.9313 - val_loss: 0.1562 - val_accuracy: 0.9321
# Epoch 77/130
# 499/499 - 2s - loss: 0.1504 - accuracy: 0.9371 - val_loss: 0.1863 - val_accuracy: 0.9141
# Epoch 78/130
# 499/499 - 2s - loss: 0.1451 - accuracy: 0.9389 - val_loss: 0.2023 - val_accuracy: 0.9087
# Epoch 79/130
# 499/499 - 2s - loss: 0.1511 - accuracy: 0.9356 - val_loss: 0.1506 - val_accuracy: 0.9414
# Epoch 80/130
# 499/499 - 2s - loss: 0.1420 - accuracy: 0.9407 - val_loss: 0.1884 - val_accuracy: 0.9203
# Epoch 81/130
# 499/499 - 2s - loss: 0.1511 - accuracy: 0.9360 - val_loss: 0.1739 - val_accuracy: 0.9257
# Epoch 82/130
# 499/499 - 2s - loss: 0.1481 - accuracy: 0.9365 - val_loss: 0.1606 - val_accuracy: 0.9287
# Epoch 83/130
# 499/499 - 2s - loss: 0.1382 - accuracy: 0.9407 - val_loss: 0.2541 - val_accuracy: 0.9029
# Epoch 84/130
# 499/499 - 2s - loss: 0.1500 - accuracy: 0.9384 - val_loss: 0.1552 - val_accuracy: 0.9388
# Epoch 85/130
# 499/499 - 2s - loss: 0.1408 - accuracy: 0.9421 - val_loss: 0.1524 - val_accuracy: 0.9370
# Epoch 86/130
# 499/499 - 2s - loss: 0.1346 - accuracy: 0.9464 - val_loss: 0.1130 - val_accuracy: 0.9516
# Epoch 87/130
# 499/499 - 2s - loss: 0.1347 - accuracy: 0.9450 - val_loss: 0.1200 - val_accuracy: 0.9552
# Epoch 88/130
# 499/499 - 2s - loss: 0.1413 - accuracy: 0.9422 - val_loss: 0.1538 - val_accuracy: 0.9412
# Epoch 89/130
# 499/499 - 2s - loss: 0.1232 - accuracy: 0.9504 - val_loss: 0.1165 - val_accuracy: 0.9578
# Epoch 90/130
# 499/499 - 2s - loss: 0.1251 - accuracy: 0.9495 - val_loss: 0.1421 - val_accuracy: 0.9415
# Epoch 91/130
# 499/499 - 2s - loss: 0.1403 - accuracy: 0.9433 - val_loss: 0.1218 - val_accuracy: 0.9524
# Epoch 92/130
# 499/499 - 2s - loss: 0.1144 - accuracy: 0.9541 - val_loss: 0.1272 - val_accuracy: 0.9511
# Epoch 93/130
# 499/499 - 2s - loss: 0.1262 - accuracy: 0.9508 - val_loss: 0.2333 - val_accuracy: 0.9040
# Epoch 94/130
# 499/499 - 2s - loss: 0.1299 - accuracy: 0.9471 - val_loss: 0.1299 - val_accuracy: 0.9521
# Epoch 95/130
# 499/499 - 2s - loss: 0.1124 - accuracy: 0.9546 - val_loss: 0.1276 - val_accuracy: 0.9512
# Epoch 96/130
# 499/499 - 2s - loss: 0.1213 - accuracy: 0.9524 - val_loss: 0.1191 - val_accuracy: 0.9558
# Epoch 97/130
# 499/499 - 2s - loss: 0.1327 - accuracy: 0.9470 - val_loss: 0.0961 - val_accuracy: 0.9639
# Epoch 98/130
# 499/499 - 2s - loss: 0.1177 - accuracy: 0.9548 - val_loss: 0.1107 - val_accuracy: 0.9561
# Epoch 99/130
# 499/499 - 2s - loss: 0.1189 - accuracy: 0.9521 - val_loss: 0.2002 - val_accuracy: 0.9247
# Epoch 100/130
# 499/499 - 2s - loss: 0.1159 - accuracy: 0.9560 - val_loss: 0.1468 - val_accuracy: 0.9462
# Epoch 101/130
# 499/499 - 2s - loss: 0.1100 - accuracy: 0.9574 - val_loss: 0.1500 - val_accuracy: 0.9350
# Epoch 102/130
# 499/499 - 2s - loss: 0.1067 - accuracy: 0.9594 - val_loss: 0.3021 - val_accuracy: 0.8994
# Epoch 103/130
# 499/499 - 2s - loss: 0.1253 - accuracy: 0.9523 - val_loss: 0.1086 - val_accuracy: 0.9586
# Epoch 104/130
# 499/499 - 2s - loss: 0.1115 - accuracy: 0.9560 - val_loss: 0.1033 - val_accuracy: 0.9612
# Epoch 105/130
# 499/499 - 2s - loss: 0.1084 - accuracy: 0.9573 - val_loss: 0.2915 - val_accuracy: 0.9151
# Epoch 106/130
# 499/499 - 2s - loss: 0.1088 - accuracy: 0.9603 - val_loss: 0.1014 - val_accuracy: 0.9665
# Epoch 107/130
# 499/499 - 2s - loss: 0.0993 - accuracy: 0.9616 - val_loss: 0.1086 - val_accuracy: 0.9596
# Epoch 108/130
# 499/499 - 2s - loss: 0.0948 - accuracy: 0.9649 - val_loss: 0.0892 - val_accuracy: 0.9670
# Epoch 109/130
# 499/499 - 2s - loss: 0.1049 - accuracy: 0.9596 - val_loss: 0.1284 - val_accuracy: 0.9561
# Epoch 110/130
# 499/499 - 2s - loss: 0.0999 - accuracy: 0.9612 - val_loss: 0.1177 - val_accuracy: 0.9512
# Epoch 111/130
# 499/499 - 2s - loss: 0.0994 - accuracy: 0.9618 - val_loss: 0.0792 - val_accuracy: 0.9721
# Epoch 112/130
# 499/499 - 2s - loss: 0.1042 - accuracy: 0.9604 - val_loss: 0.1557 - val_accuracy: 0.9361
# Epoch 113/130
# 499/499 - 2s - loss: 0.0963 - accuracy: 0.9634 - val_loss: 0.1232 - val_accuracy: 0.9553
# Epoch 114/130
# 499/499 - 2s - loss: 0.0980 - accuracy: 0.9614 - val_loss: 0.0687 - val_accuracy: 0.9764
# Epoch 115/130
# 499/499 - 2s - loss: 0.0955 - accuracy: 0.9634 - val_loss: 0.0805 - val_accuracy: 0.9714
# Epoch 116/130
# 499/499 - 2s - loss: 0.0901 - accuracy: 0.9662 - val_loss: 0.0748 - val_accuracy: 0.9745
# Epoch 117/130
# 499/499 - 2s - loss: 0.0905 - accuracy: 0.9664 - val_loss: 0.2169 - val_accuracy: 0.9251
# Epoch 118/130
# 499/499 - 2s - loss: 0.1023 - accuracy: 0.9617 - val_loss: 0.1376 - val_accuracy: 0.9508
# Epoch 119/130
# 499/499 - 2s - loss: 0.0844 - accuracy: 0.9692 - val_loss: 0.1610 - val_accuracy: 0.9317
# Epoch 120/130
# 499/499 - 2s - loss: 0.0955 - accuracy: 0.9641 - val_loss: 0.1081 - val_accuracy: 0.9593
# Epoch 121/130
# 499/499 - 2s - loss: 0.0962 - accuracy: 0.9646 - val_loss: 0.0787 - val_accuracy: 0.9742
# Epoch 122/130
# 499/499 - 2s - loss: 0.0882 - accuracy: 0.9669 - val_loss: 0.0805 - val_accuracy: 0.9734
# Epoch 123/130
# 499/499 - 2s - loss: 0.0835 - accuracy: 0.9694 - val_loss: 0.1208 - val_accuracy: 0.9581
# Epoch 124/130
# 499/499 - 2s - loss: 0.0890 - accuracy: 0.9666 - val_loss: 0.0654 - val_accuracy: 0.9782
# Epoch 125/130
# 499/499 - 2s - loss: 0.0878 - accuracy: 0.9678 - val_loss: 0.0771 - val_accuracy: 0.9730
# Epoch 126/130
# 499/499 - 2s - loss: 0.0833 - accuracy: 0.9697 - val_loss: 0.0739 - val_accuracy: 0.9737
# Epoch 127/130
# 499/499 - 2s - loss: 0.0866 - accuracy: 0.9675 - val_loss: 0.0883 - val_accuracy: 0.9688
# Epoch 128/130
# 499/499 - 2s - loss: 0.0957 - accuracy: 0.9648 - val_loss: 0.0776 - val_accuracy: 0.9753
# Epoch 129/130
# 499/499 - 2s - loss: 0.0880 - accuracy: 0.9677 - val_loss: 0.1020 - val_accuracy: 0.9645
# Epoch 130/130
# 499/499 - 2s - loss: 0.0831 - accuracy: 0.9681 - val_loss: 0.0686 - val_accuracy: 0.9778

# %% [markdown]
# 可以看出来，只用原始的数据我们达到了87%左右的一个正确率，此时我们加上灯塔的位置在模拟一次

# %%
# rob_base = RobustScaler()
# data_plus_station = data.copy()
# station_p = [0,0,1300,5000,0,1700,0,5000,1700,5000,5000,1300]
# data_plus_station[['A01','A02','A03','A11','A12','A13','A21','A22','A23','A31','A32','A33']]=station_p
# # data_scaled = rob.fit_transform(data[['position1'  ,'position2' , 'position3' , 'position4']])
# # data_scaled.
# Out:
# [0, 0, 1300, 5000, 0, 1700, 0, 5000, 1700, 5000, 5000, 1300]

# %%
model.compile(Adam(lr=0.0001) , loss = 'sparse_categorical_crossentropy',
             metrics = ['accuracy'])
his2 = model.fit(x_train , y_train , validation_split=0.2 ,  epochs=130 ,
          batch_size=64 ,shuffle=True , verbose=2
         )
# Out:
# Epoch 1/130
# 499/499 - 2s - loss: 0.0430 - accuracy: 0.9875 - val_loss: 0.0443 - val_accuracy: 0.9867
# Epoch 2/130
# 499/499 - 2s - loss: 0.0403 - accuracy: 0.9887 - val_loss: 0.0435 - val_accuracy: 0.9883
# Epoch 3/130
# 499/499 - 2s - loss: 0.0392 - accuracy: 0.9890 - val_loss: 0.0411 - val_accuracy: 0.9888
# Epoch 4/130
# 499/499 - 2s - loss: 0.0380 - accuracy: 0.9897 - val_loss: 0.0416 - val_accuracy: 0.9868
# Epoch 5/130
# 499/499 - 2s - loss: 0.0377 - accuracy: 0.9891 - val_loss: 0.0414 - val_accuracy: 0.9883
# Epoch 6/130
# 499/499 - 2s - loss: 0.0371 - accuracy: 0.9894 - val_loss: 0.0412 - val_accuracy: 0.9856
# Epoch 7/130
# 499/499 - 2s - loss: 0.0362 - accuracy: 0.9896 - val_loss: 0.0415 - val_accuracy: 0.9872
# Epoch 8/130
# 499/499 - 2s - loss: 0.0360 - accuracy: 0.9894 - val_loss: 0.0415 - val_accuracy: 0.9887
# Epoch 9/130
# 499/499 - 2s - loss: 0.0360 - accuracy: 0.9897 - val_loss: 0.0473 - val_accuracy: 0.9867
# Epoch 10/130
# 499/499 - 2s - loss: 0.0352 - accuracy: 0.9901 - val_loss: 0.0409 - val_accuracy: 0.9871
# Epoch 11/130
# 499/499 - 2s - loss: 0.0349 - accuracy: 0.9903 - val_loss: 0.0393 - val_accuracy: 0.9880
# Epoch 12/130
# 499/499 - 2s - loss: 0.0342 - accuracy: 0.9904 - val_loss: 0.0418 - val_accuracy: 0.9880
# Epoch 13/130
# 499/499 - 2s - loss: 0.0338 - accuracy: 0.9903 - val_loss: 0.0405 - val_accuracy: 0.9875
# Epoch 14/130
# 499/499 - 2s - loss: 0.0342 - accuracy: 0.9904 - val_loss: 0.0398 - val_accuracy: 0.9877
# Epoch 15/130
# 499/499 - 2s - loss: 0.0333 - accuracy: 0.9907 - val_loss: 0.0385 - val_accuracy: 0.9883
# Epoch 16/130
# 499/499 - 2s - loss: 0.0330 - accuracy: 0.9903 - val_loss: 0.0394 - val_accuracy: 0.9873
# Epoch 17/130
# 499/499 - 2s - loss: 0.0332 - accuracy: 0.9904 - val_loss: 0.0371 - val_accuracy: 0.9886
# Epoch 18/130
# 499/499 - 2s - loss: 0.0329 - accuracy: 0.9905 - val_loss: 0.0389 - val_accuracy: 0.9882
# Epoch 19/130
# 499/499 - 2s - loss: 0.0322 - accuracy: 0.9909 - val_loss: 0.0388 - val_accuracy: 0.9885
# Epoch 20/130
# 499/499 - 2s - loss: 0.0326 - accuracy: 0.9905 - val_loss: 0.0382 - val_accuracy: 0.9891
# Epoch 21/130
# 499/499 - 2s - loss: 0.0323 - accuracy: 0.9902 - val_loss: 0.0365 - val_accuracy: 0.9893
# Epoch 22/130
# 499/499 - 2s - loss: 0.0321 - accuracy: 0.9900 - val_loss: 0.0391 - val_accuracy: 0.9893
# Epoch 23/130
# 499/499 - 2s - loss: 0.0318 - accuracy: 0.9908 - val_loss: 0.0384 - val_accuracy: 0.9895
# Epoch 24/130
# 499/499 - 2s - loss: 0.0313 - accuracy: 0.9909 - val_loss: 0.0377 - val_accuracy: 0.9886
# Epoch 25/130
# 499/499 - 2s - loss: 0.0314 - accuracy: 0.9911 - val_loss: 0.0390 - val_accuracy: 0.9873
# Epoch 26/130
# 499/499 - 2s - loss: 0.0309 - accuracy: 0.9911 - val_loss: 0.0379 - val_accuracy: 0.9883
# Epoch 27/130
# 499/499 - 2s - loss: 0.0306 - accuracy: 0.9912 - val_loss: 0.0372 - val_accuracy: 0.9885
# Epoch 28/130
# 499/499 - 2s - loss: 0.0301 - accuracy: 0.9913 - val_loss: 0.0383 - val_accuracy: 0.9888
# Epoch 29/130
# 499/499 - 2s - loss: 0.0313 - accuracy: 0.9907 - val_loss: 0.0366 - val_accuracy: 0.9885
# Epoch 30/130
# 499/499 - 2s - loss: 0.0299 - accuracy: 0.9913 - val_loss: 0.0378 - val_accuracy: 0.9890
# Epoch 31/130
# 499/499 - 2s - loss: 0.0309 - accuracy: 0.9911 - val_loss: 0.0376 - val_accuracy: 0.9881
# Epoch 32/130
# 499/499 - 2s - loss: 0.0299 - accuracy: 0.9912 - val_loss: 0.0390 - val_accuracy: 0.9878
# Epoch 33/130
# 499/499 - 2s - loss: 0.0307 - accuracy: 0.9910 - val_loss: 0.0365 - val_accuracy: 0.9895
# Epoch 34/130
# 499/499 - 2s - loss: 0.0303 - accuracy: 0.9912 - val_loss: 0.0359 - val_accuracy: 0.9892
# Epoch 35/130
# 499/499 - 2s - loss: 0.0297 - accuracy: 0.9913 - val_loss: 0.0364 - val_accuracy: 0.9905
# Epoch 36/130
# 499/499 - 2s - loss: 0.0296 - accuracy: 0.9910 - val_loss: 0.0347 - val_accuracy: 0.9895
# Epoch 37/130
# 499/499 - 2s - loss: 0.0292 - accuracy: 0.9917 - val_loss: 0.0361 - val_accuracy: 0.9892
# Epoch 38/130
# 499/499 - 2s - loss: 0.0294 - accuracy: 0.9915 - val_loss: 0.0356 - val_accuracy: 0.9882
# Epoch 39/130
# 499/499 - 2s - loss: 0.0291 - accuracy: 0.9916 - val_loss: 0.0361 - val_accuracy: 0.9890
# Epoch 40/130
# 499/499 - 2s - loss: 0.0288 - accuracy: 0.9916 - val_loss: 0.0341 - val_accuracy: 0.9901
# Epoch 41/130
# 499/499 - 2s - loss: 0.0285 - accuracy: 0.9913 - val_loss: 0.0376 - val_accuracy: 0.9893
# Epoch 42/130
# 499/499 - 2s - loss: 0.0285 - accuracy: 0.9914 - val_loss: 0.0413 - val_accuracy: 0.9876
# Epoch 43/130
# 499/499 - 2s - loss: 0.0288 - accuracy: 0.9916 - val_loss: 0.0380 - val_accuracy: 0.9892
# Epoch 44/130
# 499/499 - 2s - loss: 0.0285 - accuracy: 0.9916 - val_loss: 0.0401 - val_accuracy: 0.9867
# Epoch 45/130
# 499/499 - 2s - loss: 0.0286 - accuracy: 0.9918 - val_loss: 0.0337 - val_accuracy: 0.9902
# Epoch 46/130
# 499/499 - 2s - loss: 0.0276 - accuracy: 0.9919 - val_loss: 0.0381 - val_accuracy: 0.9881
# Epoch 47/130
# 499/499 - 2s - loss: 0.0269 - accuracy: 0.9923 - val_loss: 0.0352 - val_accuracy: 0.9886
# Epoch 48/130
# 499/499 - 2s - loss: 0.0276 - accuracy: 0.9918 - val_loss: 0.0343 - val_accuracy: 0.9893
# Epoch 49/130
# 499/499 - 2s - loss: 0.0274 - accuracy: 0.9915 - val_loss: 0.0379 - val_accuracy: 0.9893
# Epoch 50/130
# 499/499 - 2s - loss: 0.0282 - accuracy: 0.9915 - val_loss: 0.0350 - val_accuracy: 0.9886
# Epoch 51/130
# 499/499 - 2s - loss: 0.0278 - accuracy: 0.9917 - val_loss: 0.0339 - val_accuracy: 0.9898
# Epoch 52/130
# 499/499 - 2s - loss: 0.0265 - accuracy: 0.9922 - val_loss: 0.0351 - val_accuracy: 0.9896
# Epoch 53/130
# 499/499 - 2s - loss: 0.0271 - accuracy: 0.9924 - val_loss: 0.0342 - val_accuracy: 0.9891
# Epoch 54/130
# 499/499 - 2s - loss: 0.0268 - accuracy: 0.9923 - val_loss: 0.0364 - val_accuracy: 0.9888
# Epoch 55/130
# 499/499 - 2s - loss: 0.0273 - accuracy: 0.9916 - val_loss: 0.0322 - val_accuracy: 0.9907
# Epoch 56/130
# 499/499 - 2s - loss: 0.0268 - accuracy: 0.9918 - val_loss: 0.0374 - val_accuracy: 0.9886
# Epoch 57/130
# 499/499 - 2s - loss: 0.0267 - accuracy: 0.9923 - val_loss: 0.0326 - val_accuracy: 0.9907
# Epoch 58/130
# 499/499 - 2s - loss: 0.0264 - accuracy: 0.9922 - val_loss: 0.0357 - val_accuracy: 0.9903
# Epoch 59/130
# 499/499 - 2s - loss: 0.0259 - accuracy: 0.9927 - val_loss: 0.0351 - val_accuracy: 0.9891
# Epoch 60/130
# 499/499 - 2s - loss: 0.0269 - accuracy: 0.9916 - val_loss: 0.0356 - val_accuracy: 0.9886
# Epoch 61/130
# 499/499 - 2s - loss: 0.0265 - accuracy: 0.9922 - val_loss: 0.0360 - val_accuracy: 0.9873
# Epoch 62/130
# 499/499 - 2s - loss: 0.0262 - accuracy: 0.9926 - val_loss: 0.0328 - val_accuracy: 0.9896
# Epoch 63/130
# 499/499 - 2s - loss: 0.0261 - accuracy: 0.9923 - val_loss: 0.0358 - val_accuracy: 0.9893
# Epoch 64/130
# 499/499 - 2s - loss: 0.0263 - accuracy: 0.9923 - val_loss: 0.0354 - val_accuracy: 0.9881
# Epoch 65/130
# 499/499 - 2s - loss: 0.0257 - accuracy: 0.9923 - val_loss: 0.0325 - val_accuracy: 0.9906
# Epoch 66/130
# 499/499 - 2s - loss: 0.0260 - accuracy: 0.9919 - val_loss: 0.0358 - val_accuracy: 0.9896
# Epoch 67/130
# 499/499 - 2s - loss: 0.0258 - accuracy: 0.9926 - val_loss: 0.0367 - val_accuracy: 0.9882
# Epoch 68/130
# 499/499 - 2s - loss: 0.0257 - accuracy: 0.9924 - val_loss: 0.0325 - val_accuracy: 0.9910
# Epoch 69/130
# 499/499 - 2s - loss: 0.0255 - accuracy: 0.9926 - val_loss: 0.0339 - val_accuracy: 0.9911
# Epoch 70/130
# 499/499 - 2s - loss: 0.0251 - accuracy: 0.9921 - val_loss: 0.0321 - val_accuracy: 0.9910
# Epoch 71/130
# 499/499 - 2s - loss: 0.0249 - accuracy: 0.9924 - val_loss: 0.0326 - val_accuracy: 0.9896
# Epoch 72/130
# 499/499 - 2s - loss: 0.0250 - accuracy: 0.9924 - val_loss: 0.0321 - val_accuracy: 0.9902
# Epoch 73/130
# 499/499 - 2s - loss: 0.0249 - accuracy: 0.9925 - val_loss: 0.0348 - val_accuracy: 0.9892
# Epoch 74/130
# 499/499 - 2s - loss: 0.0249 - accuracy: 0.9927 - val_loss: 0.0321 - val_accuracy: 0.9906
# Epoch 75/130
# 499/499 - 2s - loss: 0.0251 - accuracy: 0.9925 - val_loss: 0.0326 - val_accuracy: 0.9900
# Epoch 76/130
# 499/499 - 2s - loss: 0.0245 - accuracy: 0.9927 - val_loss: 0.0328 - val_accuracy: 0.9895
# Epoch 77/130
# 499/499 - 2s - loss: 0.0253 - accuracy: 0.9923 - val_loss: 0.0355 - val_accuracy: 0.9893
# Epoch 78/130
# 499/499 - 2s - loss: 0.0250 - accuracy: 0.9925 - val_loss: 0.0347 - val_accuracy: 0.9892
# Epoch 79/130
# 499/499 - 2s - loss: 0.0241 - accuracy: 0.9927 - val_loss: 0.0364 - val_accuracy: 0.9890
# Epoch 80/130
# 499/499 - 2s - loss: 0.0246 - accuracy: 0.9924 - val_loss: 0.0376 - val_accuracy: 0.9881
# Epoch 81/130
# 499/499 - 2s - loss: 0.0239 - accuracy: 0.9931 - val_loss: 0.0357 - val_accuracy: 0.9891
# Epoch 82/130
# 499/499 - 2s - loss: 0.0241 - accuracy: 0.9925 - val_loss: 0.0315 - val_accuracy: 0.9917
# Epoch 83/130
# 499/499 - 2s - loss: 0.0239 - accuracy: 0.9928 - val_loss: 0.0323 - val_accuracy: 0.9911
# Epoch 84/130
# 499/499 - 2s - loss: 0.0238 - accuracy: 0.9929 - val_loss: 0.0355 - val_accuracy: 0.9902
# Epoch 85/130
# 499/499 - 2s - loss: 0.0238 - accuracy: 0.9928 - val_loss: 0.0325 - val_accuracy: 0.9905
# Epoch 86/130
# 499/499 - 2s - loss: 0.0242 - accuracy: 0.9924 - val_loss: 0.0344 - val_accuracy: 0.9897
# Epoch 87/130
# 499/499 - 2s - loss: 0.0246 - accuracy: 0.9921 - val_loss: 0.0323 - val_accuracy: 0.9905
# Epoch 88/130
# 499/499 - 2s - loss: 0.0230 - accuracy: 0.9934 - val_loss: 0.0352 - val_accuracy: 0.9905
# Epoch 89/130
# 499/499 - 2s - loss: 0.0239 - accuracy: 0.9926 - val_loss: 0.0344 - val_accuracy: 0.9912
# Epoch 90/130
# 499/499 - 2s - loss: 0.0239 - accuracy: 0.9926 - val_loss: 0.0334 - val_accuracy: 0.9898
# Epoch 91/130
# 499/499 - 2s - loss: 0.0241 - accuracy: 0.9924 - val_loss: 0.0359 - val_accuracy: 0.9908
# Epoch 92/130
# 499/499 - 2s - loss: 0.0236 - accuracy: 0.9929 - val_loss: 0.0327 - val_accuracy: 0.9912
# Epoch 93/130
# 499/499 - 2s - loss: 0.0235 - accuracy: 0.9925 - val_loss: 0.0341 - val_accuracy: 0.9896
# Epoch 94/130
# 499/499 - 2s - loss: 0.0231 - accuracy: 0.9928 - val_loss: 0.0358 - val_accuracy: 0.9906
# Epoch 95/130
# 499/499 - 2s - loss: 0.0229 - accuracy: 0.9935 - val_loss: 0.0323 - val_accuracy: 0.9901
# Epoch 96/130
# 499/499 - 2s - loss: 0.0234 - accuracy: 0.9928 - val_loss: 0.0330 - val_accuracy: 0.9916
# Epoch 97/130
# 499/499 - 2s - loss: 0.0227 - accuracy: 0.9933 - val_loss: 0.0341 - val_accuracy: 0.9902
# Epoch 98/130
# 499/499 - 2s - loss: 0.0235 - accuracy: 0.9924 - val_loss: 0.0333 - val_accuracy: 0.9898
# Epoch 99/130
# 499/499 - 2s - loss: 0.0233 - accuracy: 0.9929 - val_loss: 0.0327 - val_accuracy: 0.9903
# Epoch 100/130
# 499/499 - 2s - loss: 0.0223 - accuracy: 0.9933 - val_loss: 0.0306 - val_accuracy: 0.9910
# Epoch 101/130
# 499/499 - 2s - loss: 0.0230 - accuracy: 0.9930 - val_loss: 0.0331 - val_accuracy: 0.9895
# Epoch 102/130
# 499/499 - 2s - loss: 0.0225 - accuracy: 0.9931 - val_loss: 0.0304 - val_accuracy: 0.9915
# Epoch 103/130
# 499/499 - 2s - loss: 0.0231 - accuracy: 0.9928 - val_loss: 0.0335 - val_accuracy: 0.9896
# Epoch 104/130
# 499/499 - 2s - loss: 0.0227 - accuracy: 0.9927 - val_loss: 0.0315 - val_accuracy: 0.9911
# Epoch 105/130
# 499/499 - 2s - loss: 0.0220 - accuracy: 0.9932 - val_loss: 0.0313 - val_accuracy: 0.9920
# Epoch 106/130
# 499/499 - 2s - loss: 0.0224 - accuracy: 0.9933 - val_loss: 0.0359 - val_accuracy: 0.9902
# Epoch 107/130
# 499/499 - 2s - loss: 0.0226 - accuracy: 0.9928 - val_loss: 0.0334 - val_accuracy: 0.9903
# Epoch 108/130
# 499/499 - 2s - loss: 0.0224 - accuracy: 0.9930 - val_loss: 0.0313 - val_accuracy: 0.9907
# Epoch 109/130
# 499/499 - 2s - loss: 0.0227 - accuracy: 0.9932 - val_loss: 0.0330 - val_accuracy: 0.9907
# Epoch 110/130
# 499/499 - 2s - loss: 0.0218 - accuracy: 0.9931 - val_loss: 0.0312 - val_accuracy: 0.9906
# Epoch 111/130
# 499/499 - 2s - loss: 0.0229 - accuracy: 0.9928 - val_loss: 0.0342 - val_accuracy: 0.9892
# Epoch 112/130
# 499/499 - 2s - loss: 0.0217 - accuracy: 0.9931 - val_loss: 0.0308 - val_accuracy: 0.9912
# Epoch 113/130
# 499/499 - 2s - loss: 0.0215 - accuracy: 0.9933 - val_loss: 0.0389 - val_accuracy: 0.9896
# Epoch 114/130
# 499/499 - 2s - loss: 0.0220 - accuracy: 0.9931 - val_loss: 0.0322 - val_accuracy: 0.9915
# Epoch 115/130
# 499/499 - 2s - loss: 0.0222 - accuracy: 0.9930 - val_loss: 0.0330 - val_accuracy: 0.9897
# Epoch 116/130
# 499/499 - 2s - loss: 0.0217 - accuracy: 0.9932 - val_loss: 0.0338 - val_accuracy: 0.9902
# Epoch 117/130
# 499/499 - 2s - loss: 0.0218 - accuracy: 0.9930 - val_loss: 0.0348 - val_accuracy: 0.9896
# Epoch 118/130
# 499/499 - 2s - loss: 0.0211 - accuracy: 0.9937 - val_loss: 0.0315 - val_accuracy: 0.9913
# Epoch 119/130
# 499/499 - 2s - loss: 0.0214 - accuracy: 0.9937 - val_loss: 0.0328 - val_accuracy: 0.9906
# Epoch 120/130
# 499/499 - 2s - loss: 0.0207 - accuracy: 0.9939 - val_loss: 0.0329 - val_accuracy: 0.9920
# Epoch 121/130
# 499/499 - 2s - loss: 0.0217 - accuracy: 0.9930 - val_loss: 0.0309 - val_accuracy: 0.9912
# Epoch 122/130
# 499/499 - 2s - loss: 0.0221 - accuracy: 0.9931 - val_loss: 0.0325 - val_accuracy: 0.9907
# Epoch 123/130
# 499/499 - 2s - loss: 0.0222 - accuracy: 0.9934 - val_loss: 0.0312 - val_accuracy: 0.9912
# Epoch 124/130
# 499/499 - 2s - loss: 0.0212 - accuracy: 0.9936 - val_loss: 0.0320 - val_accuracy: 0.9915
# Epoch 125/130
# 499/499 - 2s - loss: 0.0222 - accuracy: 0.9928 - val_loss: 0.0327 - val_accuracy: 0.9908
# Epoch 126/130
# 499/499 - 2s - loss: 0.0213 - accuracy: 0.9937 - val_loss: 0.0353 - val_accuracy: 0.9888
# Epoch 127/130
# 499/499 - 2s - loss: 0.0213 - accuracy: 0.9935 - val_loss: 0.0311 - val_accuracy: 0.9910
# Epoch 128/130
# 499/499 - 2s - loss: 0.0209 - accuracy: 0.9934 - val_loss: 0.0340 - val_accuracy: 0.9896
# Epoch 129/130
# 499/499 - 2s - loss: 0.0203 - accuracy: 0.9938 - val_loss: 0.0320 - val_accuracy: 0.9907
# Epoch 130/130
# 499/499 - 2s - loss: 0.0205 - accuracy: 0.9936 - val_loss: 0.0311 - val_accuracy: 0.9912

# %%
import seaborn as sns
a= his1.history['accuracy']
a1 =his2.history['accuracy']
a.extend(a1)
                                   
b = his1.history['val_accuracy']
b1 = his2.history['val_accuracy']
b.extend(b1)
a
# Out:
# [0.531384289264679,
#  0.6636657118797302,
#  0.7609084248542786,
#  0.7813293933868408,
#  0.7888892292976379,
#  0.7926848530769348,
#  0.7935945391654968,
#  0.798582136631012,
#  0.7934063076972961,
#  0.7977665662765503,
#  0.7971391677856445,
#  0.802064061164856,
#  0.8005897402763367,
#  0.8031619787216187,
#  0.8043539524078369,
#  0.8095611333847046,
#  0.806894838809967,
#  0.8107531666755676,
#  0.8143919110298157,
#  0.8178738355636597,
#  0.8227987289428711,
#  0.8305153846740723,
#  0.8351265788078308,
#  0.8397377729415894,
#  0.8442548513412476,
#  0.8468897938728333,
#  0.8487719297409058,
#  0.8467329740524292,
#  0.8572728037834167,
#  0.8566768169403076,
#  0.8597195744514465,
#  0.854826033115387,
#  0.8480190634727478,
#  0.8492110967636108,
#  0.8641111850738525,
#  0.8638602495193481,
#  0.8746196627616882,
#  0.8771291375160217,
#  0.8750901818275452,
#  0.8881081342697144,
#  0.8856614232063293,
#  0.8891746997833252,
#  0.889676570892334,
#  0.8919978737831116,
#  0.8795445561408997,
#  0.89240562915802,
#  0.902224063873291,
#  0.8982715606689453,
#  0.899369478225708,
#  0.9037297368049622,
#  0.9023495316505432,
#  0.9057059288024902,
#  0.9085605144500732,
#  0.9133285284042358,
#  0.9093447327613831,
#  0.9080272316932678,
#  0.9106621742248535,
#  0.9228332042694092,
#  0.9188494086265564,
#  0.915743887424469,
#  0.9207001328468323,
#  0.9131089448928833,
#  0.9211079478263855,
#  0.9204805493354797,
#  0.921515703201294,
#  0.9230214357376099,
#  0.9240879416465759,
#  0.924527108669281,
#  0.9298911690711975,
#  0.9292637705802917,
#  0.9298597574234009,
#  0.9266915321350098,
#  0.9324319958686829,
#  0.9329025149345398,
#  0.9384861588478088,
#  0.9312713742256165,
#  0.9370745420455933,
#  0.9388939142227173,
#  0.9355688691139221,
#  0.9406819343566895,
#  0.9360080361366272,
#  0.9365413188934326,
#  0.9406819343566895,
#  0.9384233951568604,
#  0.9420621991157532,
#  0.9463596940040588,
#  0.9450108408927917,
#  0.9421562552452087,
#  0.9504061937332153,
#  0.9494651556015015,
#  0.9432541728019714,
#  0.9541077017784119,
#  0.9508453607559204,
#  0.947112500667572,
#  0.9545782208442688,
#  0.9523824453353882,
#  0.9470497965812683,
#  0.954829216003418,
#  0.9520687460899353,
#  0.9559584856033325,
#  0.9574328064918518,
#  0.959377646446228,
#  0.952256977558136,
#  0.9559898376464844,
#  0.957275927066803,
#  0.9603186845779419,
#  0.9616361856460571,
#  0.9649298787117004,
#  0.9595972299575806,
#  0.9612283706665039,
#  0.9617616534233093,
#  0.9604128003120422,
#  0.9633928537368774,
#  0.9613852500915527,
#  0.9633928537368774,
#  0.9662473797798157,
#  0.9664356112480164,
#  0.9617303013801575,
#  0.9691960215568542,
#  0.9641143083572388,
#  0.9646161794662476,
#  0.9669374823570251,
#  0.9693842530250549,
#  0.9666237831115723,
#  0.9678471684455872,
#  0.969697892665863,
#  0.9674707651138306,
#  0.9647730588912964,
#  0.9676589369773865,
#  0.9681295156478882,
#  0.9875152707099915,
#  0.9887073040008545,
#  0.9890210032463074,
#  0.9897111058235168,
#  0.9890837073326111,
#  0.989397406578064,
#  0.9896483421325684,
#  0.989397406578064,
#  0.9897424578666687,
#  0.9901188611984253,
#  0.9903384447097778,
#  0.9903698563575745,
#  0.990307092666626,
#  0.9903698563575745,
#  0.990746259689331,
#  0.9902757406234741,
#  0.9904325604438782,
#  0.99046391248703,
#  0.9909030795097351,
#  0.99046391248703,
#  0.9902129769325256,
#  0.9900248050689697,
#  0.9908403754234314,
#  0.9908717274665833,
#  0.9910913109779358,
#  0.9911226630210876,
#  0.991216778755188,
#  0.9913108944892883,
#  0.9906834959983826,
#  0.9913108944892883,
#  0.9910913109779358,
#  0.9911540746688843,
#  0.9909971952438354,
#  0.9912481307983398,
#  0.9912795424461365,
#  0.9909971952438354,
#  0.9916559457778931,
#  0.9915304780006409,
#  0.9915931820869446,
#  0.9916245937347412,
#  0.9913108944892883,
#  0.9914363622665405,
#  0.9915931820869446,
#  0.9916245937347412,
#  0.9918441772460938,
#  0.9919382929801941,
#  0.9922519326210022,
#  0.9918127655982971,
#  0.9915304780006409,
#  0.9914677143096924,
#  0.9916559457778931,
#  0.9921578764915466,
#  0.9924401640892029,
#  0.9922519326210022,
#  0.9916245937347412,
#  0.9918441772460938,
#  0.9923146963119507,
#  0.9921892285346985,
#  0.9926910996437073,
#  0.9915931820869446,
#  0.9921892285346985,
#  0.9925969839096069,
#  0.9923460483551025,
#  0.9923146963119507,
#  0.9923460483551025,
#  0.9919382929801941,
#  0.9925656318664551,
#  0.992408812046051,
#  0.9925969839096069,
#  0.99212646484375,
#  0.992408812046051,
#  0.9924401640892029,
#  0.9924715161323547,
#  0.9927225112915039,
#  0.9925029277801514,
#  0.9927225112915039,
#  0.9922833442687988,
#  0.9924715161323547,
#  0.9926910996437073,
#  0.992408812046051,
#  0.9930675625801086,
#  0.9925029277801514,
#  0.9927852153778076,
#  0.9929420351982117,
#  0.9927538633346558,
#  0.992408812046051,
#  0.9920951128005981,
#  0.9933812022209167,
#  0.9926283955574036,
#  0.9926283955574036,
#  0.992408812046051,
#  0.992879331111908,
#  0.9925342798233032,
#  0.9928165674209595,
#  0.9934753179550171,
#  0.9927852153778076,
#  0.9932871460914612,
#  0.9924401640892029,
#  0.992879331111908,
#  0.9932871460914612,
#  0.9930047988891602,
#  0.9930989146232605,
#  0.9928165674209595,
#  0.9926597476005554,
#  0.9932243824005127,
#  0.993318498134613,
#  0.9928165674209595,
#  0.9929734468460083,
#  0.9931930303573608,
#  0.9930989146232605,
#  0.9928165674209595,
#  0.9931302666664124,
#  0.9932557344436646,
#  0.9930989146232605,
#  0.9930047988891602,
#  0.9932243824005127,
#  0.993036150932312,
#  0.9936635494232178,
#  0.9936949014663696,
#  0.9939144849777222,
#  0.9930047988891602,
#  0.9930989146232605,
#  0.9934126138687134,
#  0.9935694336891174,
#  0.9928165674209595,
#  0.9936949014663696,
#  0.993506669998169,
#  0.9934126138687134,
#  0.99378901720047,
#  0.9936321973800659]

# %%
print(len(a),len(b))
# Out:
# 260 260

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize = (16,16))
plt.plot(a)
plt.plot(b)
plt.title('model acc')
plt.ylabel('acc')
plt.xlabel('epoch')
plt.annotate('lr0.001 reset to 0.0001', xy=(130, 0.98), xytext=(130, 0.6),
 arrowprops=dict(facecolor='#6E726D', shrink=0.05))
plt.legend(['train acc', 'val acc'], loc='upper left')
plt.show()

# %%
model.save('Station_PositionPlus.h5')

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=14)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import itertools
plt.style.use('fivethirtyeight')
# from sklearn.metrics import plot_confusion_matrix
predictions = model.predict_classes(x_test , batch_size=40 ,verbose = 0)
classes = [0,1]
cm = confusion_matrix(y_test, predictions)
fig = plt.figure(figsize=(16,8))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title("test dataset \n Confusion Matrix", fontsize=14)
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)
normalize = True
fmt = '.2f' if normalize else 'd'
thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, format(cm[i, j], fmt),
             horizontalalignment="center",
             color="white" if cm[i, j] > thresh else "black")
# Out:
# C:\anaconda\lib\site-packages\tensorflow\python\keras\engine\sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
accuracy = ((cm[0,0]+cm[1,1])/cm.sum())*100
print(f'在训练组的正确率{accuracy}%')
# Out:
# 在训练组的正确率97.70149553347385%

# %% [markdown]
# # 很好
# 我们加入基站的数据作为一个辅助量，得出超乎想象的一个正确率，说明了基站的位置作为常量在检测信号是否干否有着非常重要的意义。

# %%
path = 'C:\\Users\\luzheng\\建模\\任务五核弹爆炸好模型\\'
classification = tf.keras.models.load_model(path+'第2次分类结果.h5')
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import itertools
plt.style.use('fivethirtyeight')
# from sklearn.metrics import plot_confusion_matrix
predictions = classification.predict_classes(x_test , batch_size=40 ,verbose = 0)
classes = [0,1]
cm = confusion_matrix(y_test, predictions)
fig = plt.figure(figsize=(16,8))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title("test dataset \n Confusion Matrix", fontsize=14)
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)
normalize = True
fmt = '.2f' if normalize else 'd'
thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, format(cm[i, j], fmt),
             horizontalalignment="center",
             color="white" if cm[i, j] > thresh else "black")
# Out:
# C:\anaconda\lib\site-packages\tensorflow\python\keras\engine\sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
from sklearn.metrics import precision_score ,recall_score ,roc_auc_score , accuracy_score , f1_score ,classification_report

print('Recall Score: {:.4f}'.format(recall_score(y_train, classification.predict_classes(x_train))))
print('Precision Score: {:.4f}'.format(precision_score(y_train, classification.predict_classes(x_train))))
print('F1 Score: {:.4f}'.format(f1_score(y_train, classification.predict_classes(x_train))))
print('Accuracy Score: {:.4f}'.format(accuracy_score(y_train, classification.predict_classes(x_train))))
# Out:
# Recall Score: 0.9950
# Precision Score: 0.9987
# F1 Score: 0.9968
# Accuracy Score: 0.9966
